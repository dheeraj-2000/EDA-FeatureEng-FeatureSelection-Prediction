# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(np.arange(0,20).reshape(4,5), columns=['col1', 'col2', 'col3', 'col4', 'col5'], index=['row1', 'row2','row3', 'row4'])

# %%
df
# Out:
#       col1  col2  col3  col4  col5
# row1     0     1     2     3     4
# row2     5     6     7     8     9
# row3    10    11    12    13    14
# row4    15    16    17    18    19

# %%
df.loc['row1']
# Out:
# col1    0
# col2    1
# col3    2
# col4    3
# col5    4
# Name: row1, dtype: int64

# %%
type(df.loc['row1'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## read table

# %%
url = 'link'
df = pd.read_html(url, match='some column', header=0)

# %%
import requests
import pandas as pd

url = 'http://www.ffiec.gov/census/report.aspx?year=2011&state=01&report=demographic&msa=11500'
html = requests.get(url).content
df_list = pd.read_html(html)
df = df_list[-1]
# print(df)
df = pd.DataFrame(df)

# %%
df
# Out:
#     County Code  Tract Code Tract Income Level  \
# 0            15        1.00           Moderate
# 1            15        2.00             Middle
# 2            15        3.00           Moderate
# 3            15        4.00           Moderate
# 4            15        5.00                Low
# 5            15        6.00                Low
# 6            15        8.00           Moderate
# 7            15        9.00              Upper
# 8            15       10.00              Upper
# 9            15       11.00              Upper
# 10           15       12.00             Middle
# 11           15       13.00           Moderate
# 12           15       14.00             Middle
# 13           15       15.00             Middle
# 14           15       16.00             Middle
# 15           15       17.00              Upper
# 16           15       18.00             Middle
# 17           15       19.00             Middle
# 18           15       20.00             Middle
# ...

# %%
import requests
import pandas as pd

url = 'https://www.iplt20.com/points-table/2020'
html = requests.get(url).content
df_list = pd.read_html(html)
df = df_list[-1]
# print(df)
df = pd.DataFrame(df)
df
# Out:
#    Unnamed: 0                              Team  Pld  Won  Lost  Tied  N/R  \
# 0           1          Chennai Super Kings  CSK    1    1     0     0    0
# 1           2                Delhi Capitals  DC    0    0     0     0    0
# 2           3        Kolkata Knight Riders  KKR    0    0     0     0    0
# 3           4             Kings XI Punjab  KXIP    0    0     0     0    0
# 4           5  Royal Challengers Bangalore  RCB    0    0     0     0    0
# 5           6              Rajasthan Royals  RR    0    0     0     0    0
# 6           7          Sunrisers Hyderabad  SRH    0    0     0     0    0
# 7           8                Mumbai Indians  MI    1    0     1     0    0
#
#    Net RR       For   Against  Pts Form
# 0   0.486  166/19.2    162/20    2    W
# 1   0.000       NaN       NaN    0  NaN
# 2   0.000       NaN       NaN    0  NaN
# 3   0.000       NaN       NaN    0  NaN
# 4   0.000       NaN       NaN    0  NaN
# 5   0.000       NaN       NaN    0  NaN
# ...

# %%
df.rename(columns={'Unnamed: 0': 'Ranking'}, inplace=True)

# %%
# df

# %%
import requests
import pandas as pd

url = 'https://www.iplt20.com/stats/2020/most-runs'
html = requests.get(url).content
df_list = pd.read_html(html)
df = df_list[-1]
# print(df)
df = pd.DataFrame(df)
df
# Out:
#     POS                PLAYER  Mat  Inns  NO  Runs   HS    Avg  BF      SR  \
# 0     1        Ambati  Rayudu    1     1   0    71   71  71.00  48  147.91
# 1     2       Faf  du Plessis    1     1   1    54  54*      -  43  125.58
# 2     3       Marcus  Stoinis    1     1   0    53   53  53.00  21  252.38
# 3     4       Saurabh  Tiwary    1     1   0    42   42  42.00  31  135.48
# 4     5         Shreyas  Iyer    1     1   0    39   39  39.00  32  121.87
# 5     6      Quinton  de Kock    1     1   0    33   33  33.00  20  165.00
# 6     7         Rishabh  Pant    1     1   0    31   31  31.00  29  106.89
# 7     8       Mayank  Agarwal    1     1   1    22  22*      -  26   84.61
# 8     9             KL  Rahul    1     1   0    21   21  21.00  19  110.52
# 9    10       Kieron  Pollard    1     1   0    18   18  18.00  14  128.57
# 10   11           Sam  Curran    1     1   0    18   18  18.00   6  300.00
# ...

# %%
df1 = df[:3]
df1
# Out:
#    POS           PLAYER  Mat  Inns  NO  Runs   HS    Avg  BF      SR  100  50  \
# 0    1   Ambati  Rayudu    1     1   0    71   71  71.00  48  147.91    0   1
# 1    2  Faf  du Plessis    1     1   1    54  54*      -  43  125.58    0   1
# 2    3  Saurabh  Tiwary    1     1   0    42   42  42.00  31  135.48    0   0
#
#    4s  6s
# 0   6   3
# 1   5   0
# 2   3   1

# %%
df2 = df[['POS', 'PLAYER', 'Runs']].head(3)
df2
# Out:
#    POS           PLAYER  Runs
# 0    1   Ambati  Rayudu    71
# 1    2  Faf  du Plessis    54
# 2    3  Saurabh  Tiwary    42

# %%
import plotly.express as px
# import plotly.graph_objs as go
# col = ['red', 'green', 'blue']
# col = {
#     'Ambati Rayudu': 'orangered',
#     'Faf du Plessis': 'green',
#     'Saurabh Tiwary': 'yellow'
# }
fig = px.bar(df2, x='PLAYER', y='Runs',
             hover_data=['POS','PLAYER', 'Runs'], color=["orange", "green", "blue"], 
        color_discrete_map={"orange":"orangered", "blue":"lightblue", "green": "green"},
                 height=700, width=800)

fig.update_layout(
#     title="Top 3 Batsman (Most run scorer)",
    xaxis_title="Batsman",
    yaxis_title="Runs Scored",
    legend_title="Legend Title",
    font=dict(
        family="Arial",
        size=18,
        color="RebeccaPurple"
    )
)

fig.update_layout(
    title={
        'text': "Top 3 Batsman (Most run scorer)",
        'y':0.95,
        'x':0.45,
        'xanchor': 'center',
        'yanchor': 'top'})

fig.show()
# Out:
# <div>
#
#
#             <div id="060c9780-cfe3-43c9-987d-780815dc1037" class="plotly-graph-div" style="height:700px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("060c9780-cfe3-43c9-987d-780815dc1037")) {
#                     Plotly.newPlot(
#                         '060c9780-cfe3-43c9-987d-780815dc1037',
# ...

# %%
df
# Out:
#     POS                PLAYER  Mat  Inns  NO  Runs   HS    Avg  BF      SR  \
# 0     1        Ambati  Rayudu    1     1   0    71   71  71.00  48  147.91
# 1     2       Faf  du Plessis    1     1   1    54  54*      -  43  125.58
# 2     3       Marcus  Stoinis    1     1   0    53   53  53.00  21  252.38
# 3     4       Saurabh  Tiwary    1     1   0    42   42  42.00  31  135.48
# 4     5         Shreyas  Iyer    1     1   0    39   39  39.00  32  121.87
# 5     6      Quinton  de Kock    1     1   0    33   33  33.00  20  165.00
# 6     7         Rishabh  Pant    1     1   0    31   31  31.00  29  106.89
# 7     8       Mayank  Agarwal    1     1   1    22  22*      -  26   84.61
# 8     9             KL  Rahul    1     1   0    21   21  21.00  19  110.52
# 9    10       Kieron  Pollard    1     1   0    18   18  18.00  14  128.57
# 10   11           Sam  Curran    1     1   0    18   18  18.00   6  300.00
# ...

# %%
dfx = df.sort_values(by=['SR'], ascending=False).head(3)

# %%
import numpy as np
x = np.arange(1, 4)
dfx['Pso'] = x
dfx
# Out:
#     POS           PLAYER  Mat  Inns  NO  Runs  HS    Avg  BF      SR  100  50  \
# 10   11      Sam  Curran    1     1   0    18  18  18.00   6  300.00    0   0
# 24   25   Anrich  Nortje    1     1   1     3  3*      -   1  300.00    0   0
# 2     3  Marcus  Stoinis    1     1   0    53  53  53.00  21  252.38    0   1
#
#     4s  6s  Pso
# 10   1   2    1
# 24   0   0    2
# 2    7   3    3

# %%
df.sort_values(by=['Avg'], ascending=False)
# Out:
#     POS                PLAYER  Mat  Inns  NO  Runs   HS    Avg  BF      SR  \
# 0     1        Ambati  Rayudu    1     1   0    71   71  71.00  48  147.91
# 17   18      Shimron  Hetmyer    1     1   0     7    7   7.00  13   53.84
# 18   19           Axar  Patel    1     1   0     6    6   6.00   9   66.66
# 2     3       Marcus  Stoinis    1     1   0    53   53  53.00  21  252.38
# 19   20         Prithvi  Shaw    1     1   0     5    5   5.00   9   55.55
# 3     4       Saurabh  Tiwary    1     1   0    42   42  42.00  31  135.48
# 22   23  Ravichandran  Ashwin    1     1   0     4    4   4.00   6   66.66
# 21   22         Shane  Watson    1     1   0     4    4   4.00   5   80.00
# 4     5         Shreyas  Iyer    1     1   0    39   39  39.00  32  121.87
# 5     6      Quinton  de Kock    1     1   0    33   33  33.00  20  165.00
# 6     7         Rishabh  Pant    1     1   0    31   31  31.00  29  106.89
# ...

# %%
import requests
import pandas as pd
bowling_stats_data_url = 'https://www.iplt20.com/stats/2020/most-wickets'
# most_run_data_url = 'https://www.iplt20.com/stats/2020/most-runs'
html = requests.get(bowling_stats_data_url).content
df_list_bowling_stat = pd.read_html(html)
df_bowling_stat = df_list_bowling_stat[-1]

# %%
data = pd.DataFrame(df_bowling_stat)

# %%
data
# Out:
#     POS                PLAYER  Mat  Inns   Ov  Runs  Wkts  BBI    Avg   Econ  \
# 0     1       Mohammad  Shami    1     2  4.2    18     3    0   6.00   4.15
# 1     2          Lungi  Ngidi    1     1  4.0    38     3    0  12.66   9.50
# 2     3  Ravichandran  Ashwin    1     1  1.0     2     2    0   1.00   2.00
# 3     4     Sheldon  Cottrell    1     1  4.0    24     2    0  12.00   6.00
# 4     5        Kagiso  Rabada    1     1  4.0    28     2    0  14.00   7.00
# 5     6        Deepak  Chahar    1     1  4.0    32     2    0  16.00   8.00
# 6     7       Marcus  Stoinis    1     1  3.0    29     2    0  14.50   9.66
# 7     8      Ravindra  Jadeja    1     1  4.0    42     2    0  21.00  10.50
# 8     9           Axar  Patel    1     1  4.0    14     1    0  14.00   3.50
# 9    10        Piyush  Chawla    1     1  4.0    21     1    0  21.00   5.25
# 10   11         Ravi  Bishnoi    1     1  4.0    22     1    0  22.00   5.50
# ...

# %%
data = data[data.Avg != '-']

# %%
import numpy as np
df_bowl_best_avg = data.sort_values(by=['Avg'], ascending=True).head(3)
x = np.arange(1, 4)
df_bowl_best_avg['Position'] = x

# %%
data_bowl_stats_best_avg = df_bowl_best_avg[['Position', 'PLAYER', 'Avg']].dropna(how='any').head(3)
data_bowl_stats_best_avg
# Out:
#    Position                PLAYER    Avg
# 2         1  Ravichandran  Ashwin   1.00
# 3         2     Sheldon  Cottrell  12.00
# 1         3          Lungi  Ngidi  12.66

# %%
# df = df[df.line_race != 0]

# %%
import plotly.express as px

# %%
fig = px.bar(data_bowl_stats_best_avg, x='PLAYER', y='Avg',opacity=0.9,text='Avg', hover_data=['Position','PLAYER', 'Avg'], color='PLAYER')

fig.update_traces(texttemplate='%{text:.4s}', textposition='outside')
fig.update_layout(uniformtext_minsize=12, uniformtext_mode='hide')

fig.update_layout(xaxis_title="Bowlers",
                                yaxis_title="Average",
                                legend_title="Players",
                                font=dict(
                                    family="Arial",
                                    size=16,
                                    color="RebeccaPurple"
                                ))

fig.update_layout(title={'text': "Top 3 Bowlers with Best Bowling Average",
                                        'y':0.95,
                                        'x':0.40,
                                        'xanchor': 'center',
                                        'yanchor': 'top'})

fig.show()
# Out:
# <div>
#
#
#             <div id="9631be53-68aa-489f-94ea-ba2f1df950fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9631be53-68aa-489f-94ea-ba2f1df950fb")) {
#                     Plotly.newPlot(
#                         '9631be53-68aa-489f-94ea-ba2f1df950fb',
# ...

# %%
import requests
import pandas as pd


bowling_stats_data_url =  'https://www.iplt20.com/stats/2020/most-runs'


# most_run_data_url = 'https://www.iplt20.com/stats/2020/most-runs'
html = requests.get(bowling_stats_data_url).content
df_list_bowling_stat = pd.read_html(html)
df_bat_stat = df_list_bowling_stat[-1]

df_bat_stat = pd.DataFrame(df_bat_stat)

df_bat_stat.head(20)
# data_run = 'https://www.iplt20.com/stats/2020/most-run'
# Out:
#     POS               PLAYER  Mat  Inns  NO  Runs   HS    Avg  BF      SR  \
# 0     1      Mayank  Agarwal    1     1   0    89   89  89.00  60  148.33
# 1     2       Ambati  Rayudu    1     1   0    71   71  71.00  48  147.91
# 2     3      Faf  du Plessis    1     1   1    54  54*      -  43  125.58
# 3     4      Marcus  Stoinis    1     1   0    53   53  53.00  21  252.38
# 4     5      Saurabh  Tiwary    1     1   0    42   42  42.00  31  135.48
# 5     6        Shreyas  Iyer    1     2   1    39   39  39.00  32  121.87
# 6     7        Rishabh  Pant    1     2   1    33   31  33.00  31  106.45
# 7     8     Quinton  de Kock    1     1   0    33   33  33.00  20  165.00
# 8     9            KL  Rahul    1     1   0    21   21  21.00  19  110.52
# 9    10  Krishnappa  Gowtham    1     1   0    20   20  20.00  14  142.85
# 10   11      Kieron  Pollard    1     1   0    18   18  18.00  14  128.57
# 11   12          Sam  Curran    1     1   0    18   18  18.00   6  300.00
# ...

# %%
df_bat_stat.loc[df_bat_stat['PLAYER'] == 'Mayank Agarwal']
# Out:
# Empty DataFrame
# Columns: [POS, PLAYER, Mat, Inns, NO, Runs, HS, Avg, BF, SR, 100, 50, 4s, 6s]
# Index: []

# %%
df_ply = pd.read_csv("/home/dheeraj/my_projects/my_project_env/practice/motion_detector/IPL2020_Dashnoard/csk.csv")

# %%
df_ply = pd.DataFrame(df_ply)
# df_ply[1:]
df_ply = df_ply.set_axis(['player'], axis=1, inplace=False)

# %%
df_ply = np.array(df_ply['player'])

# %%
df_ply
# Out:
# array(['Ambati Rayudu', 'Faf du Plessis', 'Sam Curran', 'Ravindra Jadeja',
#        'Shane Watson', 'Murali Vijay', 'MS Dhoni', 'Lungi Ngidi',
#        'Deepak Chahar', 'Piyush Chawla', 'KM Asif', 'Dwayne Bravo',
#        'Imran Tahir', 'Narayan Jagadeesan', 'Karn Sharma', 'Kedar Jadhav',
#        'Mitchell Santner', 'Monu Kumar', 'Ruturaj Gaikwad',
#        'Shardul Thakur', 'Josh Hazlewood', 'R Sai Kishore'], dtype=object)

# %%
df_bat_stat.loc[df_bat_stat['PLAYER']== ]
# Out:
# Empty DataFrame
# Columns: [POS, PLAYER, Mat, Inns, NO, Runs, HS, Avg, BF, SR, 100, 50, 4s, 6s]
# Index: []

# %%
df_bat_stat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 14 columns):
# POS       35 non-null int64
# PLAYER    35 non-null object
# Mat       35 non-null int64
# Inns      35 non-null int64
# NO        35 non-null int64
# Runs      35 non-null int64
# HS        35 non-null object
# Avg       35 non-null object
# BF        35 non-null int64
# SR        35 non-null float64
# 100       35 non-null int64
# 50        35 non-null int64
# 4s        35 non-null int64
# 6s        35 non-null int64
# dtypes: float64(1), int64(10), object(3)
# memory usage: 4.0+ KB

# %%
df_ply.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 1 columns):
# player    22 non-null object
# dtypes: object(1)
# memory usage: 304.0+ bytes

# %%
import requests
import pandas as pd


bowling_stats_data_url =  'https://www.icccricketschedule.com/ipl-2020-mumbai-indians-mi-full-schedule-time-table/'


# most_run_data_url = 'https://www.iplt20.com/stats/2020/most-runs'
html = requests.get(bowling_stats_data_url).content
df_list_bowling_stat = pd.read_html(html)
df_bat_stat = df_list_bowling_stat[-1]

df_bat_stat = pd.DataFrame(df_bat_stat)

df_bat_stat.to_csv("/home/dheeraj/my_projects/my_project_env/practice/motion_detector/IPL2020_Dashnoard/mi_schedule.csv")

# %%
from IPython.display import Image
Image(filename='/home/dheeraj/my_projects/my_project_env/practice/motion_detector/IPL2020_Dashnoard/csk_fixture.jpg')

# %%
image = pd.read_csv('/home/dheeraj/my_projects/my_project_env/practice/motion_detector/IPL2020_Dashnoard/csk_.csv')
    # st.image(image, use_column_width=True)
image
# Out:
#     Unnamed: 0  Match No                                       Match Center  \
# 0            0         1   Mumbai Indians (MI) Vs Chennai Super Kings (CSK)
# 1            1         4  Rajasthan Royals (RR) Vs Chennai Super Kings (...
# 2            2         7   Chennai Super Kings (CSK) Vs Delhi Capitals (DC)
# 3            3        14  Chennai Super Kings (CSK) Vs Sun Risers Hydera...
# 4            4        18  Kings XI Punjab (KXIP) Vs Chennai Super Kings ...
# 5            5        21  Kolkata Knight Riders (KKR) Vs Chennai Super K...
# 6            6        25  Chennai Super Kings (CSK) Vs Royal Challengers...
# 7            7        29  Sun Risers Hyderabad (SRH) Vs Chennai Super Ki...
# 8            8        34   Delhi Capitals (DC) Vs Chennai Super Kings (CSK)
# 9            9        37  Chennai Super Kings (CSK) Vs Rajasthan Royals ...
# 10          10        41   Chennai Super Kings (CSK) Vs Mumbai Indians (MI)
# ...

# %%
imag= image[['Match No', 'Match Center', 'Date', 'Day', 'Time India (IST)', 'Time UAE', 'Venuue']]

# %%
imag = imag.style.hide_index()

# %%
imag
# Out:
# <style  type="text/css" >
# </style><table id="T_a29272ce_fbfb_11ea_965d_89e87e19cee7" ><thead>    <tr>        <th class="col_heading level0 col0" >Match No</th>        <th class="col_heading level0 col1" >Match Center</th>        <th class="col_heading level0 col2" >Date</th>        <th class="col_heading level0 col3" >Day</th>        <th class="col_heading level0 col4" >Time India (IST)</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_a29272ce_fbfb_11ea_965d_89e87e19cee7row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_a29272ce_fbfb_11ea_965d_89e87e19cee7row0_col1" class="data row0 col1" >Mumbai Indians (MI) Vs Chennai Super Kings (CSK)</td>
#                         <td id="T_a29272ce_fbfb_11ea_965d_89e87e19cee7row0_col2" class="data row0 col2" >19 September 2020</td>
#                         <td id="T_a29272ce_fbfb_11ea_965d_89e87e19cee7row0_col3" class="data row0 col3" >Saturday</td>
# ...

# %%
    
    

import requests
import pandas as pd


bowling_stats_data_url =  'https://www.icccricketschedule.com/vivo-ipl-2020-schedule-team-venue-time-table-pdf-point-table-ranking-winning-prediction/'


# most_run_data_url = 'https://www.iplt20.com/stats/2020/most-runs'
html = requests.get(bowling_stats_data_url).content
df_list_bowling_stat = pd.read_html(html)
df_bat_stat = df_list_bowling_stat[-1]

df_bat_stat = pd.DataFrame(df_bat_stat)

# df_bat_stat.to_csv("/home/dheeraj/my_projects/my_project_env/practice/motion_detector/IPL2020_Dashnoard/csk_.csv")

# %%
df_bat_stat
# Out:
#                        0                                                  1
# 0      IPL 2020 Schedule         From 19 September 2020 to 10 November 2020
# 1                   Host                                          IPL India
# 2           Host Country                         UAE (United Arab Emirates)
# 3          Administrator  Board of Control for Cricket in India (BCCI) a...
# 4                 Format                 T20 (20 Over Cricket League Match)
# 5          Opening Match  19 September 2020 | Chennai Super Kings (CSK) ...
# 6            Qualifier-1                                    TBD | TBD | TBD
# 7             Eliminator                                    TBD | TBD | TBD
# 8            Qualifier-2                                    TBD | TBD | TBD
# 9            Final Match                       10 November 2020 | TBD | TBD
# 10     Participants Team                                                  8
# ...

# %%
# from bs4 import BeautifulSoup
# import urllib.request
# score_page = 'https://www.espncricinfo.com/series/8048/game/1216534/sunrisers-hyderabad-vs-royal-challengers-bangalore-3rd-match-indian-premier-league-2020-21'
# while True:
#     page = urllib.request.urlopen(score_page)
#     soup = BeautifulSoup(page, 'html.parser')
#     result = soup.find_all('description') 
#     message = input('Do you want to refresh scores? [Y/N]')
#     if message == 'Y':
#         print('------------------------------------------')
#         for match in result:
#             print(match.get_text())
#     elif message == 'N':
#         break
#     else:
#         print('Please enter “Y” or “N” only.')
#         continue
import http.client

conn = http.client.HTTPSConnection("dev132-cricket-live-scores-v1.p.rapidapi.com")

headers = {
    'x-rapidapi-host': "dev132-cricket-live-scores-v1.p.rapidapi.com",
    'x-rapidapi-key': "248495d713mshc71142f6c933d23p1fcabfjsn3ce39f09e353"
    }

conn.request("GET", "/scorecards.php?seriesid=2141&matchid=43431", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"message":"You are not subscribed to this API."}

# %%
from pycricbuzz import Cricbuzz
import json
c = Cricbuzz()
matches = c.matches()
print (json.dumps(matches,indent=4)) #for pretty prinitng
# Out:
# [
#     {
#         "id": "30345",
#         "srs": "Indian Premier League 2020",
#         "mnum": "3rd Match",
#         "type": "T20",
#         "mchstate": "inprogress",
#         "status": "Sunrisers HYD need 18 runs in 6 balls",
#         "venue_name": "Dubai International Cricket Stadium",
#         "venue_location": "Dubai, United Arab Emirates",
#         "toss": "Sunrisers Hyderabad elect to bowl",
#         "official": {
#             "umpire1": {
#                 "id": "8862",
#                 "name": "Nitin Menon",
#                 "country": "IND"
#             },
#             "umpire2": {
#                 "id": "7537",
#                 "name": "Anil Dandekar",
#                 "country": "IND"
#             },
#             "umpire3": {
#                 "id": "8294",
#                 "name": "Anil Chaudhary",
#                 "country": "IND"
#             },
#             "referee": {
#                 "id": "9225",
# ...

# %%
def match_info(mid):
    c = Cricbuzz()
    minfo = c.matchinfo(mid)
    print(json.dumps(minfo, indent=4, sort_keys=True))
    
match_info(30345)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-160-0da6b9d59c4b> in <module>
#       4     print(json.dumps(minfo, indent=4, sort_keys=True))
#       5
# ----> 6 match_info(30345)
#
# <ipython-input-160-0da6b9d59c4b> in match_info(mid)
#       1 def match_info(mid):
#       2     c = Cricbuzz()
# ----> 3     minfo = c.matchinfo(mid)
#       4     print(json.dumps(minfo, indent=4, sort_keys=True))
#       5
#
# ~/my_projects/my_project_env/lib/python3.6/site-packages/pycricbuzz/cricbuzz.py in matchinfo(self, mid)
#      28                 d = {}
#      29                 d['id'] = mid
# ---> 30                 url = "http://mapps.cricbuzz.com/cbzios/match/" + mid
#      31                 match = self.crawl_url(url)
#      32
#
# TypeError: must be str, not int

# %%
df.to_json(orient='record')
